# %% [markdown]
# <a href="https://colab.research.google.com/github/Shrivastava-Aditya/Machine-Learning-Fundamentals/blob/main/Underfitting_overfitting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Overfitting/Underfitting
#
# Overfitting
# - High **Variance** && low **Bias**
#
# Undefitting
# - Low **Variance** && High **Bias**
#
# Bias : bias refers to how much we ignore the data.
#
# Variance : refers to how dependent our model is on the data
#
# Solution
#
# Validation Set:
# 1. Pre-trained data set.
# 2. Different from training data and test data.

# %% [markdown]
# ![image.png](data:image/png;base64,...)
